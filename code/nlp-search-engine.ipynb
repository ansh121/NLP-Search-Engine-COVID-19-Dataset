# %%
import spacy
nlp = spacy.load('en_core_web_sm') 

from sutime import SUTime
sutime = SUTime(mark_time_ranges=True, include_range=True)

import csv, sqlite3
import pickle
import re

# %%
# variables
query_file_path = "../possible-questions.txt"

create_database_flag=False
dataset_path="../dataset/covid-19/required_only/"
database_path=r"..\dataset\covid-19\mysql_database\covid19.db"

parsed_parameter_save_path='../dataset/covid-19/parsed_parameters.pickle'

additional_stopwords=['case', 'find', 'covid', 'coronavirus', 'covid-19', 'covid19', 'world']

assign_base_words={
    'recover' : ['recover','recovery','cure','heal'],
    'death' : ['death','fatality','fatal','demise','decease','die','expire'],
    'confirm': ['confirm'],
    'active' : ['active', 'live'],
    'maximum' : ['maximum', 'high', 'max', 'maximal', 'most'],
    'minimum' : ['minimum', 'low', 'least', 'min'],
    'average' : ['average', 'avg', 'normally', 'usually', 'generally'],
    'state' : ['state', 'province'],
    'country' : ['country', 'region', 'nation', 'place']
}

# %%
def read_queries(query_file_path):
    queries=[]
    with open(query_file_path,"r") as f:
        for line in f.readlines():
            line = line[:-1]
            if(line):
                queries.append(line)

    return queries

def print_entities(sentence):
	doc = nlp(sentence)
	print("----> Entities:")
	for ent in doc.ents: 
		print("-------->",ent.text, ent.start_char, ent.end_char, ent.label_)

def print_tokens(sentence):
	doc = nlp(sentence) 
	print("----> Tokens:")
	for token in doc: 
		print("-------->", token.text, token.pos_, token.dep_)

# %%
queries = read_queries(query_file_path)

# %%
def add_stopwords(additional_stopwords):
    for word in additional_stopwords:
        nlp.vocab[word].is_stop=True

def get_reverse_dict(assign_base_words):
    reverse_base_word_dict={}
    for base, l in assign_base_words.items():
        for item in l:
            doc = nlp(item)
            item = doc[0].lemma_
            reverse_base_word_dict[item]=base

    return reverse_base_word_dict

# %%
add_stopwords(additional_stopwords)
reverse_base_word_dict = get_reverse_dict(assign_base_words)

# %%
def csv_to_table(cur, path, csv_name, table_name):
    with open(dataset_path+csv_name,'r') as fin:
        dr = csv.DictReader(fin)
        to_db=[tuple(i.values()) for i in dr]
    
    count=len(dr.fieldnames)
    bindings="?, "*count

    cur.executemany("INSERT INTO "+table_name+" VALUES ("+bindings[:-2]+");", to_db)

def create_database():
    con = sqlite3.connect(database_path)
    cur = con.cursor()

    tables=[("worldwide_aggregate"),("reference"),("timeseries"),("us")]
    for table in tables:
        cur.execute("DROP TABLE IF EXISTS "+table+";")

    cur.execute("create table worldwide_aggregate(Date Date NOT NULL, Confirmed BIGINT NOT NULL, Recovered BIGINT NOT NULL, Deaths BIGINT NOT NULL, Increase_rate FLOAT default NULL, PRIMARY KEY (Date));")

    csv_to_table(cur,dataset_path,"worldwide-aggregate.csv", tables[0])

    cur.execute("create table us(Date Date NOT NULL, Admin2 VARCHAR(100) NOT NULL, Province_State VARCHAR(100) NOT NULL, Confirmed BIGINT NOT NULL, Deaths BIGINT NOT NULL, Country_Region VARCHAR(100) NOT NULL, PRIMARY KEY (Date, Admin2, Province_State));")

    csv_to_table(cur,dataset_path,"us_simplified.csv", tables[3])

    cur.execute("create table reference(UID INT NOT NULL, iso2 VARCHAR(20), iso3 VARCHAR(20), code3 INT, FIPS INT, Admin2 VARCHAR(100) NOT NULL, Province_State VARCHAR(100) NOT NULL, Country_Region VARCHAR(100) NOT NULL, Lat FLOAT NOT NULL, Long_ FLOAT NOT NULL, Combined_Key VARCHAR(100), Popolation BIGINT NOT NULL, PRIMARY KEY (UID));")

    csv_to_table(cur,dataset_path,"reference.csv", tables[1])

    cur.execute("create table timeseries(Date Date NOT NULL, Country_Region VARCHAR(100) NOT NULL, Province_State VARCHAR(100), Confirmed BIGINT NOT NULL, Recovered BIGINT NOT NULL, Deaths BIGINT NOT NULL, PRIMARY KEY (Date, Country_Region, Province_State));")

    csv_to_table(cur,dataset_path,"time-series-19-covid-combined.csv", tables[2])

    con.commit()

    # with open('../dataset/covid-19/mysql_database/dump.sql','w') as fp:
    #     for line in con.iterdump():
    #         fp.write('%s\n' % line)

    con.close()

# %%
if create_database_flag:
    create_database()

# %%
def generate_country_state_list():
    con = sqlite3.connect(database_path)

    cur = con.execute("SELECT DISTINCT Province_State, Country_Region FROM reference;")
    # cur = con.execute("SELECT count(*) FROM reference;")

    countries_only=[]
    states_only=[]
    state_country_dict={}

    for row in cur:
        countries_only.append(row[1].lower())
        if row[0]:
            states_only.append(row[0].lower())
            state_country_dict[row[0].lower()]=row[1].lower()

    con.close()
    return countries_only, states_only, state_country_dict

# %%
countries_only, states_only, state_country_dict=generate_country_state_list()

# %%
def identify_places(places):
    place_dict={
        'no_match':[],
        'states':[],
        'countries':[]
    }

    for place in places:
        place=place.lower()
        if place in states_only:
            place_dict['states'].append(place)
        elif place in countries_only:
            place_dict['countries'].append(place)
        else:
            place_dict['no_match'].append(place)
    
    return place_dict

def get_places(entities):
    places=[]
    for ent in entities:
        if ent.label_ == 'GPE':
            places.append(ent.text)
    
    place_dict=identify_places(places)
    
    return place_dict

def find_regex(s):
    X = re.search('....-..-..', s)
    if(X):
        return X.group()
    
    X = re.search('....-..', s)
    if(X):
        return X.group()

def process_interval(time):
    # print(time)
    if(time['begin']>time['end']):
        time['begin'], time['end']=time['end'], time['begin']

    start_time=time['begin']
    YMD=start_time.split('-')
    if(len(YMD)==2):
        YMD.append('XX')

    YMD[1]=YMD[1] if YMD[1]!='XX' else '01'
    YMD[2]=YMD[2] if YMD[2]!='XX' else '01'
    # YMD.reverse()
    begin='-'.join(YMD)

    end_time=time['end']
    YMD=end_time.split('-')
    if(len(YMD)==2):
        YMD.append('XX')

    YMD[1]=YMD[1] if YMD[1]!='XX' else '12'
    YMD[2]=YMD[2] if YMD[2]!='XX' else '31'
    # YMD.reverse()
    end='-'.join(YMD)

    time['begin']=begin
    time['end']=end

    return time

def get_time_duration(query):
    time={}
    parsed=sutime.parse(query)

    if len(parsed)==1:
        item=parsed[0]

        if item['type']=='DATE':
            if item['value'] != 'PRESENT_REF':
                time['begin']=item['value']
                time['end']=item['value']

        elif item['type']=='DURATION' and type(item['value'])==type(time):
            time['begin']=item['value']['begin']
            time['end']=item['value']['end']
    
    elif len(parsed)==2 and parsed[0]['type']=='DATE' and parsed[1]['type']=='DATE':
        time['begin']=min(parsed[0]['value'], parsed[1]['value'])
        time['end']=max(parsed[0]['value'], parsed[1]['value'])

    # print(parsed)
    # for item in parsed:
    #     time.append(item['value'])

    if len(time)==0:
        time['begin']='XXXX-XX-XX'
        time['end']='XXXX-XX-XX'
    
    
    time['begin']=find_regex(time['begin'])
    time['end']=find_regex(time['end'])
    # print(time)
    time=process_interval(time)

    return time

def remove_unnecessary(query):
    doc=nlp(query)

    for ent in doc.ents:
        if ent.label_=='GPE' or ent.label_=='DATE':
            query=query.replace(ent.text,"")
    # print(query)

    query=query.lower()
    doc=nlp(query)
    query=' '.join([token.lemma_ for token in doc])

    for word,base in reverse_base_word_dict.items():
        # query=query.replace(word,base)
        query = ' '.join(base if w == word else w for w in query.split())

    doc=nlp(query)
    for token in doc:
        if token.is_stop==True or token.dep_=='prep' or token.dep_=='punct':
            # query=query.replace(token.text,"")
            query = ' '.join("" if w == token.text else w for w in query.split())
    
    return query

def get_case_and_function_type(query):
    processed_query = remove_unnecessary(query)
    # print(query)
    # print(processed_query)

    case_types = ['confirm','recover','death','increase rate','active']
    function_types = ['maximum', 'minimum', 'average', 'sum']

    final_case=""
    for case in case_types:
        if(processed_query.find(case)>=0):
            final_case = case
            break
    
    if final_case=="":
        final_case='confirm'

    final_func=""
    for func in function_types:
        if(processed_query.find(func)>=0):
            final_func = func
            break
    
    if final_func=="":
        final_func='sum'
    
    return final_case, final_func

def get_operation_type(query):
    operation_type = ['state', 'country']

    query=query.lower()
    doc=nlp(query)
    query=' '.join([token.lemma_ for token in doc])

    for word,base in reverse_base_word_dict.items():
        # query=query.replace(word,base)
        query = ' '.join(base if w == word else w for w in query.split())
    
    doc=nlp(query)
    for token in doc:
        if token.dep_!='compound':
            if token.text == 'state' or token.text == 'country':
                return token.text

    return 'cases'

def parse_parameters(query):
    doc=nlp(query)
    entities=doc.ents

    place = get_places(entities)
    time_duration = get_time_duration(query)
    case_type, function_type = get_case_and_function_type(query)
    operation_type = get_operation_type(query)

    parameters={
        'query':query,
        'Place':place,
        'Time Duration': time_duration,
        'Case Type': case_type,
        'Function Type': function_type,
        'Operation Type': operation_type
        }
    return parameters

# %%
def process_query(query):
    # print(query)
    parameters=parse_parameters(query)
    # print_entities(query)
    #print_tokens(sent)
    # doc=nlp(query)
    # print([chunk.text for chunk in doc.noun_chunks])
    # print(parameters)
    # print()
    return parameters

# %%
parameter_list=[]
for q in queries:
    parameter_list.append(process_query(q))

with open(parsed_parameter_save_path, 'wb') as f:
    pickle.dump(parameter_list, f)

# %%
parameter_list
# Out:
# [{'query': 'Which country saw highest number of death in the month of April?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-04-01', 'end': 'XXXX-04-31'},
#   'Case Type': 'death',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'Which country was last to be affected by virus?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'country'},
#  {'query': 'Which country was first to reach 1lakh cases?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'country'},
#  {'query': 'Which country was first to reach 50000 deaths?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'sum',
#   'Operation Type': 'country'},
#  {'query': 'Which country was slowest to reach 1000 deaths?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'sum',
#   'Operation Type': 'country'},
#  {'query': 'Country having maximum number of active cases till now?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'active',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'Country having minimum number of death ratio.',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'minimum',
#   'Operation Type': 'country'},
#  {'query': 'Country having minimum number of death ratio till september.',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2020-09-01', 'end': '2020-09-31'},
#   'Case Type': 'death',
#   'Function Type': 'minimum',
#   'Operation Type': 'country'},
#  {'query': 'Country having minimum number of death ratio till between may and august.',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2020-08-01', 'end': '2021-05-31'},
#   'Case Type': 'death',
#   'Function Type': 'minimum',
#   'Operation Type': 'country'},
#  {'query': 'State having minimum number of death ratio.',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'minimum',
#   'Operation Type': 'state'},
#  {'query': 'State having minimum number of death ratio till september.',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2020-09-01', 'end': '2020-09-31'},
#   'Case Type': 'death',
#   'Function Type': 'minimum',
#   'Operation Type': 'state'},
#  {'query': 'State having minimum number of death ratio till between may and august.',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2020-08-01', 'end': '2021-05-31'},
#   'Case Type': 'death',
#   'Function Type': 'minimum',
#   'Operation Type': 'state'},
#  {'query': 'Which month saw the highest increase rate?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'increase rate',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'Which month after June saw the highest increase rate?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2020-07-01', 'end': '2020-07-31'},
#   'Case Type': 'increase rate',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'Which month between September and December saw the highest increase rate?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'increase rate',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'In which month maximum number of new cases were found?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'Which country saw highest number of death in the month of April?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-04-01', 'end': 'XXXX-04-31'},
#   'Case Type': 'death',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'Which country saw highest number of death between April to August?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-04-01', 'end': 'XXXX-08-31'},
#   'Case Type': 'death',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'Which day saw the highest increase in number of cases in the world?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'Which day saw the highest increase in number of deaths in the world?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'Which day saw the highest increase in number of new cases in the world?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'Average number of deaths per day till now? ',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'average',
#   'Operation Type': 'cases'},
#  {'query': 'In which month maximum number of new cases were found in world?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'State having maximum number of active cases in USA till now?',
#   'Place': {'no_match': ['usa'], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'active',
#   'Function Type': 'maximum',
#   'Operation Type': 'state'},
#  {'query': 'Country having minimum number of recovery ratio till April?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2021-04-01', 'end': '2021-04-31'},
#   'Case Type': 'recover',
#   'Function Type': 'minimum',
#   'Operation Type': 'country'},
#  {'query': 'Country having minimum number of recovery ratio between June to october?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-06-01', 'end': 'XXXX-10-31'},
#   'Case Type': 'recover',
#   'Function Type': 'minimum',
#   'Operation Type': 'country'},
#  {'query': 'Country having maximum number of new cases in May?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2021-05-01', 'end': '2021-05-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'Which country registered highest cases in April 2020?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2020-04-01', 'end': '2020-04-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'Which country registered highest percentage of population being affected?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'Which country has highest number of deaths registered?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'Which country has lowest number of deaths registered in the month of May 2020?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2020-05-01', 'end': '2020-05-31'},
#   'Case Type': 'death',
#   'Function Type': 'minimum',
#   'Operation Type': 'country'},
#  {'query': 'Which country has the best recovery rate?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'recover',
#   'Function Type': 'sum',
#   'Operation Type': 'country'},
#  {'query': 'Which country has the highest recovered population?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'recover',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'Which country has lost most of their population to COVID?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'Which country saw the highest jump in confirmed cases between May and June 2020?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2020-06-01', 'end': '2021-05-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'Which month saw the lowest recorded confirmed cases?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'minimum',
#   'Operation Type': 'cases'},
#  {'query': 'When did the highest number of cases were registered?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'When did most people die because of COVID?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'Which state of US was worst affected?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['us']},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'state'},
#  {'query': 'Which state recorded the lowest deaths?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'minimum',
#   'Operation Type': 'state'},
#  {'query': 'Which month saw the highest rise in confirmed cases?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'On which day, the confirmed cases increased the most?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'On which day, lowest deaths occured?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'minimum',
#   'Operation Type': 'cases'},
#  {'query': 'What is the total number of confirmed cases in the upper hemisphere?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'What percentage of the total population was affected by COVID?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'How many people died due to COVID?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'What is the overall recovery rate?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'recover',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'Recovery cases in Bombay, India?',
#   'Place': {'no_match': ['bombay'], 'states': [], 'countries': ['india']},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'recover',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'which country has the highest number of cases in a single state?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'which place has the highest number of cases in US?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['us']},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'state having maximum number of cases?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'state'},
#  {'query': 'maximum number of cases in state Alabama?',
#   'Place': {'no_match': [], 'states': ['alabama'], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'Country having maximum number of cases?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'maximum number of cases in country Australia?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['australia']},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of cases found in Afganistan?',
#   'Place': {'no_match': ['afganistan'], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of Cases found in Afganistan?',
#   'Place': {'no_match': ['afganistan'], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of case found in Afganistan?',
#   'Place': {'no_match': ['afganistan'], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of Case found in Afganistan?',
#   'Place': {'no_match': ['afganistan'], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of cases found in Colombia till july?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['colombia']},
#   'Time Duration': {'begin': '2021-07-01', 'end': '2021-07-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of new cases found in France in april?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['france']},
#   'Time Duration': {'begin': '2021-04-01', 'end': '2021-04-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of new cases found in Greece between april to september?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['greece']},
#   'Time Duration': {'begin': 'XXXX-04-01', 'end': 'XXXX-09-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number cases recovered in Hungary?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['hungary']},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'recover',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of cases recovered in Iceland till May?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['iceland']},
#   'Time Duration': {'begin': '2021-05-01', 'end': '2021-05-31'},
#   'Case Type': 'recover',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of new cases recovered in Indonesia in May?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['indonesia']},
#   'Time Duration': {'begin': '2021-05-01', 'end': '2021-05-31'},
#   'Case Type': 'recover',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of new cases recovered in india from March to December?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['india']},
#   'Time Duration': {'begin': 'XXXX-03-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'recover',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of deaths in india?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['india']},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of deaths in china till august?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['china']},
#   'Time Duration': {'begin': '2020-08-01', 'end': '2020-08-31'},
#   'Case Type': 'death',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of deaths in US in august?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['us']},
#   'Time Duration': {'begin': '2020-08-01', 'end': '2020-08-31'},
#   'Case Type': 'death',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of deaths in poland between august and december?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['poland']},
#   'Time Duration': {'begin': '2020-08-01', 'end': '2020-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'country having maximum number of deaths?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'country having maximum number of deaths till june?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2021-06-01', 'end': '2021-06-31'},
#   'Case Type': 'death',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'country having maximum number of recovery cases?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'recover',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'country having maximum number of recovery cases till july?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2021-07-01', 'end': '2021-07-31'},
#   'Case Type': 'recover',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'country having maximum number of cases?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'country'},
#  {'query': 'state having maximum number of cases till september in US?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['us']},
#   'Time Duration': {'begin': '2020-09-01', 'end': '2020-09-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'state'},
#  {'query': 'state having maximum number of deaths in US?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['us']},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'maximum',
#   'Operation Type': 'state'},
#  {'query': 'state having maximum number of deaths till june in Australia?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['australia']},
#   'Time Duration': {'begin': '2021-06-01', 'end': '2021-06-31'},
#   'Case Type': 'death',
#   'Function Type': 'maximum',
#   'Operation Type': 'state'},
#  {'query': 'state having maximum number of recovery cases in US?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['us']},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'recover',
#   'Function Type': 'maximum',
#   'Operation Type': 'state'},
#  {'query': 'state having maximum number of recovery cases till July in Canada?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['canada']},
#   'Time Duration': {'begin': '2021-07-01', 'end': '2021-07-31'},
#   'Case Type': 'recover',
#   'Function Type': 'maximum',
#   'Operation Type': 'state'},
#  {'query': 'state having maximum number of cases in China?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['china']},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'state'},
#  {'query': 'state having maximum number of cases till September in Netherlands?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['netherlands']},
#   'Time Duration': {'begin': '2020-09-01', 'end': '2020-09-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'state'},
#  {'query': 'what are the total number of covid cases found in the world till september?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2020-09-01', 'end': '2020-09-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'what is the maximum increase rate found till now?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'increase rate',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of cases found in world?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of cases found in world till july?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2021-07-01', 'end': '2021-07-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of new cases found in world in april?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2021-04-01', 'end': '2021-04-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of new cases found in world between april to september?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-04-01', 'end': 'XXXX-09-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number cases recovred in world?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of cases recovred in world till may?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of new cases recovred in world in may?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2021-05-01', 'end': '2021-05-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of new cases recovred in world from march to december?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-03-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of deaths in world?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of deaths in world till august?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2020-08-01', 'end': '2020-08-31'},
#   'Case Type': 'death',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of deaths in world in august?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2020-08-01', 'end': '2020-08-31'},
#   'Case Type': 'death',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'total number of deaths in world between august and december?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2020-08-01', 'end': '2020-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'In which month maximum number of cases were found in world?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'what is the maximum increase rate found till between july to decemer?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2021-07-01', 'end': '2021-07-31'},
#   'Case Type': 'increase rate',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'In which month maximum number of cases were recovered in world?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'recover',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'In which month maximum number of deaths were found in world?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'death',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'},
#  {'query': 'Total number of cases in India till now?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['india']},
#   'Time Duration': {'begin': 'XXXX-01-01', 'end': 'XXXX-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'Total number of cases in India last month?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['india']},
#   'Time Duration': {'begin': '2020-12-01', 'end': '2020-12-31'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'Total number of cases in India on 23rd march?',
#   'Place': {'no_match': [], 'states': [], 'countries': ['india']},
#   'Time Duration': {'begin': '2021-03-23', 'end': '2021-03-23'},
#   'Case Type': 'confirm',
#   'Function Type': 'sum',
#   'Operation Type': 'cases'},
#  {'query': 'what is the maximum increase rate found till between july to december 2020?',
#   'Place': {'no_match': [], 'states': [], 'countries': []},
#   'Time Duration': {'begin': '2020-12-01', 'end': 'XXXX-07-31'},
#   'Case Type': 'increase rate',
#   'Function Type': 'maximum',
#   'Operation Type': 'cases'}]
